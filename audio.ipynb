# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text:"))
# Out:
# Enter any text:hi! hello good morning! i am akhilla have a great day deekshitha

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 48.3 MB/s eta 0:00:00
# ...

# %%
from pydub import AudioSegment
mp3_file = "/content/speech.mp3"
wav_file ="/content/speech.wav"
audio = AudioSegment.from_mp3(mp3_file)
audio.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/speech.wav'>

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/deekshi (online-audio-converter.com).wav") as source:
  audio_data = reco.record(source)
  print("Transcipt: ",reco.recognize_google(audio_data))
# Out:
# Transcipt:  hi hello good morning happy have a great day

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/drive/MyDrive/handwriting.png"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %%
# !sudo apt update
# !sudo apt-get install tesseract-ocr
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [77.5 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,726 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,245 kB]
# ...

# %%
img = Image.open(ip)
text = pytesseract .image_to_string(img)
print("Extracted text:",text)
# Out:
# Extracted text:
#
#
#
# People often ash anhich is the
#
#
#
#
#
#
#
#
#
# And. it is nok easy —_4o__aestoen

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text:")
translated = t.translate(text,src='en',dest='ta')
print("Translated text:",translated.text)
# Out:
# Enter a text:good morning
# Translated text: காலை வணக்கம்
