# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/Colab Notebooks/parent-classifer.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras.preprocessing import image

# %%
img = image.load_img('/content/images.jpg',target_size = (64,64))

# %%
from keras.preprocessing.image import img_to_array
import numpy as np

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
ig = ImageDataGenerator(rescale = 1./255)
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis = 0)
newing = ig.flow(img_array)

# %%
pred = model.predict(newing)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
pred
# Out:
# array([[0.00395359, 0.8774017 , 0.11864467]], dtype=float32)

# %%
list(pred[0]).index(max(pred[0]))
# Out:
# 1

# %%
print("birds" if pred[0][0]>0.5 else "flowers")
# Out:
# flowers
